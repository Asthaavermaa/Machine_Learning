# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import warnings

warnings.filterwarnings("ignore")

# %% [markdown]
# # Max Absolute scaling

# %%
dataset = {
    "Age": [35, 45, 28, 50, 40, 33, 55],
    "Income (USD)": [50000, 75000, 40000, 90000, 60000, 48000, 85000],
    "Number of Children": [2, 1, 0, 3, 2, 1, 2],
}

# %%
dataset = pd.DataFrame(dataset)
dataset
# Out:
#    Age  Income (USD)  Number of Children
# 0   35         50000                   2
# 1   45         75000                   1
# 2   28         40000                   0
# 3   50         90000                   3
# 4   40         60000                   2
# 5   33         48000                   1
# 6   55         85000                   2

# %% [markdown]
# In max absolute scaling we divide the value by the max value to get value to occur in between Zero and One

# %%
dataset["Income (USD)"]
# Out:
# 0    50000
# 1    75000
# 2    40000
# 3    90000
# 4    60000
# 5    48000
# 6    85000
# Name: Income (USD), dtype: int64

# %% [markdown]
# this data start from 50000 and goes to 85000 if we normalize it this data will be more simpler for our models to train with

# %%
dataset["Income (USD)"].describe()
# Out:
# count        7.000000
# mean     64000.000000
# std      19502.136635
# min      40000.000000
# 25%      49000.000000
# 50%      60000.000000
# 75%      80000.000000
# max      90000.000000
# Name: Income (USD), dtype: float64

# %%
sns.distplot(dataset["Income (USD)"])
# Out:
# <Axes: xlabel='Income (USD)', ylabel='Density'>

# %%
income = dataset["Income (USD)"]
dataset["Income (USD) Scaled"] = income / income.abs().max()
dataset["Income (USD) Scaled"]
# Out:
# 0    0.555556
# 1    0.833333
# 2    0.444444
# 3    1.000000
# 4    0.666667
# 5    0.533333
# 6    0.944444
# Name: Income (USD) Scaled, dtype: float64

# %%
sns.distplot(dataset["Income (USD) Scaled"])
# Out:
# <Axes: xlabel='Income (USD) Scaled', ylabel='Density'>

# %% [markdown]
# As we can see that the chart remained the same for condition that it will remain in range form 1 to 0

# %% [markdown]
# # Min Max Scaling

# %%
dataset['Income (USD)'].describe()
# Out:
# count        7.000000
# mean     64000.000000
# std      19502.136635
# min      40000.000000
# 25%      49000.000000
# 50%      60000.000000
# 75%      80000.000000
# max      90000.000000
# Name: Income (USD), dtype: float64

# %%
value = dataset['Income (USD)']
dataset['Income (USD) minmax'] = (value - value.min()) / (value.max() - value.min())

# %%
dataset['Income (USD) minmax'].describe()
# Out:
# count    7.000000
# mean     0.480000
# std      0.390043
# min      0.000000
# 25%      0.180000
# 50%      0.400000
# 75%      0.800000
# max      1.000000
# Name: Income (USD) minmax, dtype: float64

# %%
sns.distplot(dataset['Income (USD) minmax'])
# Out:
# <Axes: xlabel='Income (USD) minmax', ylabel='Density'>

# %% [markdown]
# # Log Transformation

# %%
dataset["Income (USD) log"] = np.log(dataset["Income (USD)"] + 1)

# %%
sns.distplot(dataset['Income (USD) log'])
# Out:
# <Axes: xlabel='Income (USD) log', ylabel='Density'>

# %% [markdown]
# if we apply this in a skewed distribution it also fixes that

# %%
dataset
# Out:
#    Age  Income (USD)  Number of Children  Income (USD) Scaled  \
# 0   35         50000                   2             0.555556
# 1   45         75000                   1             0.833333
# 2   28         40000                   0             0.444444
# 3   50         90000                   3             1.000000
# 4   40         60000                   2             0.666667
# 5   33         48000                   1             0.533333
# 6   55         85000                   2             0.944444
#
#    Income (USD) log  Income (USD) minmax
# 0         10.819798                 0.20
# 1         11.225257                 0.70
# 2         10.596660                 0.00
# 3         11.407576                 1.00
# 4         11.002117                 0.40
# 5         10.778977                 0.16
# 6         11.350418                 0.90

# %% [markdown]
# with above table we can see that all of the normalized data with columns \
# "Income (USD)" \
# "Income (USD) Scaled"	\
# "Income (USD) log"	\
# "Income (USD) minmax"

# %% [markdown]
# # Now we are Going to apply this process in a dataset to understand more how it works
