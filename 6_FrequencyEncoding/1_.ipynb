# %%
# Importing suitable libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

warnings.filterwarnings("ignore")

# %%
data = pd.read_csv('/home/amandeep/Documents/DataAnalysis/dataset/archive/feature_encoding.csv')

# %%
data.head()
# Out:
#    CUSTID PAYMENT_MODE_CARD CITY             RATING EDUCATION  \
# 0       1                 Y    A     extremely like       phd
# 1       2                 N    A               like        ms
# 2       3                 Y    C            neutral        bs
# 3       4                 Y    B  extremely dislike        bs
# 4       5                 Y    D     extremely like        ms
#
#    PURCHAGE_AMOUNT CUSTOMER_TYPE
# 0              200       Premium
# 1              100    NonPremium
# 2              130    NonPremium
# 3              120    NonPremium
# 4              160       Premium

# %% [markdown]
# ## Frequency Encoding

# %%
# As we can see that our City is in alphabet so we encode it that it will be used in out prediction midels
data.groupby('CITY').size()
# Out:
# CITY
# A    10
# B     9
# C     4
# D     3
# dtype: int64

# %%
# Now we will store it in a varibale 

tempVar = data.groupby("CITY").size()/len(data)
tempVar
# Out:
# CITY
# A    0.384615
# B    0.346154
# C    0.153846
# D    0.115385
# dtype: float64

# %%
# Now we will create a new column in we will store these calues in from of number

data['CityEncoded'] = data['CITY'].map(tempVar)
data
# Out:
#     CUSTID PAYMENT_MODE_CARD CITY             RATING EDUCATION  \
# 0        1                 Y    A     extremely like       phd
# 1        2                 N    A               like        ms
# 2        3                 Y    C            neutral        bs
# 3        4                 Y    B  extremely dislike        bs
# 4        5                 Y    D     extremely like        ms
# 5        6                 N    C               like        ms
# 6        7                 Y    B            dislike        bs
# 7        8                 N    A            neutral        ms
# 8        9                 Y    C               like       phd
# 9       10                 N    D            dislike        ms
# 10      11                 Y    A            neutral        bs
# 11      12                 N    B               like       phd
# 12      13                 Y    C            neutral        ms
# 13      14                 N    A     extremely like        ms
# ...
