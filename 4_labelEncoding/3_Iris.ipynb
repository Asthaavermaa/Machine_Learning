# %%
# Importing suitable libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

warnings.filterwarnings("ignore")

# %%
data = pd.read_csv('/home/amandeep/Documents/DataAnalysis/dataset/archive/Iris.csv')

# %%
data.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
sns.violinplot(x='Species', y='PetalWidthCm',data=data)
# Out:
# <Axes: xlabel='Species', ylabel='PetalWidthCm'>

# %%
from sklearn.preprocessing import LabelEncoder

# %%
lE = LabelEncoder()

# %%
data['labeled Species'] = lE.fit_transform(data['Species'])

# %%
sns.violinplot(x='labeled Species', y='PetalWidthCm',data=data)
# Out:
# <Axes: xlabel='labeled Species', ylabel='PetalWidthCm'>
