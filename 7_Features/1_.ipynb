# %%
# Importing suitable libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
import datetime

warnings.filterwarnings("ignore")

# %%
data = pd.read_csv('/home/amandeep/Documents/DataAnalysis/dataset/archive/Traffic data.csv', nrows=100)

# %%
data.head()
# Out:
#    ID          Datetime  Count
# 0   0  25-08-2012 00:00      8
# 1   1  25-08-2012 01:00      2
# 2   2  25-08-2012 02:00      6
# 3   3  25-08-2012 03:00      2
# 4   4  25-08-2012 04:00      2

# %%
data.shape
# Out:
# (100, 3)

# %%
data = data.loc[:, ['Datetime']]

# %%
data
# Out:
#             Datetime
# 0   25-08-2012 00:00
# 1   25-08-2012 01:00
# 2   25-08-2012 02:00
# 3   25-08-2012 03:00
# 4   25-08-2012 04:00
# ..               ...
# 95  28-08-2012 23:00
# 96  29-08-2012 00:00
# 97  29-08-2012 01:00
# 98  29-08-2012 02:00
# 99  29-08-2012 03:00
#
# [100 rows x 1 columns]

# %%
data['Datetime'] = pd.to_datetime(data.Datetime)
data.head()
# Out:
#              Datetime
# 0 2012-08-25 00:00:00
# 1 2012-08-25 01:00:00
# 2 2012-08-25 02:00:00
# 3 2012-08-25 03:00:00
# 4 2012-08-25 04:00:00

# %%
data['year'] = data['Datetime'].dt.year
data['month'] = data['Datetime'].dt.month
data['day'] = data['Datetime'].dt.day
data['quarter'] = data['Datetime'].dt.quarter
data['datOfWeek'] = data['Datetime'].dt.dayofweek
data['week'] = data['Datetime'].dt.week
data['isWeekend'] = np.where(data['datOfWeek'].isin([5,6]),1, 0)

# %%
data.head()
# Out:
#              Datetime  year  month  day  quarter  datOfWeek  week  isWeekend
# 0 2012-08-25 00:00:00  2012      8   25        3          5    34          1
# 1 2012-08-25 01:00:00  2012      8   25        3          5    34          1
# 2 2012-08-25 02:00:00  2012      8   25        3          5    34          1
# 3 2012-08-25 03:00:00  2012      8   25        3          5    34          1
# 4 2012-08-25 04:00:00  2012      8   25        3          5    34          1

# %%
data.sample(frac=1).head(10)
# Out:
#               Datetime  year  month  day  quarter  datOfWeek  week  isWeekend
# 47 2012-08-26 23:00:00  2012      8   26        3          6    34          1
# 39 2012-08-26 15:00:00  2012      8   26        3          6    34          1
# 31 2012-08-26 07:00:00  2012      8   26        3          6    34          1
# 29 2012-08-26 05:00:00  2012      8   26        3          6    34          1
# 25 2012-08-26 01:00:00  2012      8   26        3          6    34          1
# 49 2012-08-27 01:00:00  2012      8   27        3          0    35          0
# 30 2012-08-26 06:00:00  2012      8   26        3          6    34          1
# 43 2012-08-26 19:00:00  2012      8   26        3          6    34          1
# 40 2012-08-26 16:00:00  2012      8   26        3          6    34          1
# 34 2012-08-26 10:00:00  2012      8   26        3          6    34          1

# %% [markdown]
# ### Extract Time Features

# %%
data['hour'] = data['Datetime'].dt.hour
data['minute'] = data['Datetime'].dt.minute
data['second'] = data['Datetime'].dt.second

data.head(10)
# Out:
#              Datetime  year  month  day  quarter  datOfWeek  week  isWeekend  \
# 0 2012-08-25 00:00:00  2012      8   25        3          5    34          1
# 1 2012-08-25 01:00:00  2012      8   25        3          5    34          1
# 2 2012-08-25 02:00:00  2012      8   25        3          5    34          1
# 3 2012-08-25 03:00:00  2012      8   25        3          5    34          1
# 4 2012-08-25 04:00:00  2012      8   25        3          5    34          1
# 5 2012-08-25 05:00:00  2012      8   25        3          5    34          1
# 6 2012-08-25 06:00:00  2012      8   25        3          5    34          1
# 7 2012-08-25 07:00:00  2012      8   25        3          5    34          1
# 8 2012-08-25 08:00:00  2012      8   25        3          5    34          1
# 9 2012-08-25 09:00:00  2012      8   25        3          5    34          1
#
#    hour  minute  second
# 0     0       0       0
# 1     1       0       0
# 2     2       0       0
# ...

# %% [markdown]
# ### Extract date and time

# %%
data['time'] = data['Datetime'].dt.time
data['date'] = data['Datetime'].dt.date

# %%
data.sample(frac=1).head(10)
# Out:
#               Datetime  year  month  day  quarter  datOfWeek  week  isWeekend  \
# 60 2012-08-27 12:00:00  2012      8   27        3          0    35          0
# 48 2012-08-27 00:00:00  2012      8   27        3          0    35          0
# 61 2012-08-27 13:00:00  2012      8   27        3          0    35          0
# 19 2012-08-25 19:00:00  2012      8   25        3          5    34          1
# 24 2012-08-26 00:00:00  2012      8   26        3          6    34          1
# 39 2012-08-26 15:00:00  2012      8   26        3          6    34          1
# 17 2012-08-25 17:00:00  2012      8   25        3          5    34          1
# 74 2012-08-28 02:00:00  2012      8   28        3          1    35          0
# 42 2012-08-26 18:00:00  2012      8   26        3          6    34          1
# 41 2012-08-26 17:00:00  2012      8   26        3          6    34          1
#
#     hour  minute  second      time        date
# 60    12       0       0  12:00:00  2012-08-27
# ...

# %%
data['difference'] = datetime.datetime.today() - data['Datetime']

# %%
data.head(10)
# Out:
#              Datetime  year  month  day  quarter  datOfWeek  week  isWeekend  \
# 0 2012-08-25 00:00:00  2012      8   25        3          5    34          1
# 1 2012-08-25 01:00:00  2012      8   25        3          5    34          1
# 2 2012-08-25 02:00:00  2012      8   25        3          5    34          1
# 3 2012-08-25 03:00:00  2012      8   25        3          5    34          1
# 4 2012-08-25 04:00:00  2012      8   25        3          5    34          1
# 5 2012-08-25 05:00:00  2012      8   25        3          5    34          1
# 6 2012-08-25 06:00:00  2012      8   25        3          5    34          1
# 7 2012-08-25 07:00:00  2012      8   25        3          5    34          1
# 8 2012-08-25 08:00:00  2012      8   25        3          5    34          1
# 9 2012-08-25 09:00:00  2012      8   25        3          5    34          1
#
#    hour  minute  second      time        date                difference
# ...
